# %% [markdown]
# # SciGraph AI — GNN Training & Leakage Ablation on Google Colab (GPU)
#
# This notebook runs **Phase 8 (Heterogeneous GNN Training)** and **Phase 9 (Temporal Leakage Ablation Study)** on Google Colab's free GPU instance.

# %%
# 1. Verify GPU acceleration
import torch
print("PyTorch Version:", torch.__version__)
print("CUDA Available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU Device Name:", torch.cuda.get_device_name(0))

# %%
# 2. Install GPU dependencies
# !pip install -r requirements-gpu.txt

# %%
# 3. Run Heterogeneous GraphSAGE Training on GPU
# !python -m ml.gnn.train --config configs/gnn_graphsage.yaml --device cuda

# %%
# 4. Run Heterogeneous GAT Training on GPU
# !python -m ml.gnn.train --config configs/gnn_gat.yaml --device cuda
